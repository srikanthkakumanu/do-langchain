# %% [markdown]
# ## Load Environment Variables

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialize and Invoke a Model

# %%
from langchain.chat_models import init_chat_model

# model = init_chat_model(model="gpt-5-nano")
# model = init_chat_model(model="gemini-2.5-flash-lite", model_provider="google_genai")
# model = init_chat_model(model="llama-3.3-70b-versatile", model_provider="groq")
model = init_chat_model(model="llama-3.3-70b-versatile", model_provider="groq")

# %%
response = model.invoke("What is smallest particle in the atomic structure?")
response.content
# Out:
# "The smallest particle in the atomic structure is generally considered to be the **electron**.\n\nHere's why:\n\n*   **Atoms are made of subatomic particles:** Atoms themselves are composed of smaller particles.\n*   **Protons and Neutrons:** These reside in the nucleus of the atom.\n*   **Electrons:** These orbit the nucleus.\n*   **Mass comparison:** Electrons are significantly less massive than protons and neutrons.\n\nWhile there are even smaller fundamental particles that make up protons and neutrons (like quarks), when we talk about the *atomic structure*, the electron is the smallest distinct component of the atom.\n\nTherefore, the answer is the **electron**."
