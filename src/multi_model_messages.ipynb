# %%
## Text Input

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='google_genai:gemini-2.5-flash',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Ah, a fantastic question! While the Moon currently has no official capital (yet!), in the future history I'm envisioning, that honor belongs to:
#
# **Luminaris.**
#
# Nestled deep within a colossal, naturally occurring lava tube system beneath the **Oceanus Procellarum**, Luminaris is a marvel of subterranean engineering and bioluminescent growth. It's not a single city in the traditional sense, but a sprawling, interconnected network of habitats, research facilities, and agricultural domes, all carved into the bedrock and shielded from the harsh lunar surface.
#
# Its heart is the **Core Nexus**, a magnificent, multi-tiered chamber where the various lunar councils convene, trade agreements are forged, and transport arteries pulse with automated shuttles and cargo trains. The city's boulevards and residential sectors are illuminated by carefully cultivated bioluminescent fungi and plants, creating an ethereal, ever-present twilight.
#
# Above ground, visible only to daring surface expeditions or through Luminaris's myriad 'sky-eyes' (periscopic viewports), lie vast solar arrays and communication towers, stretching towards the perpetual sunlight of the lunar terminator. Below, Luminaris thrives as the administrative and scientific heart of humanity's lunar presence, a hub for asteroid mining operations, deep-space mission planning, and cutting-edge xenobotanical research. Its citizens, known as 'Selenites,' are a diverse mix of engineers, scientists, miners, and artists, all united by a pioneering spirit and a profound connection to the silent, majestic world above their heads.

# %%
## Image Input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x1160b0880>, 'last_modified': datetime.datetime(2026, 5, 16, 14, 9, 9, 220000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Welcome to **Aethelgard**, the Sky-Citadel of Selene.
#
# Perched atop the jagged, iron-rich peaks of the Terminus Range, Aethelgard is the crowning jewel and primary capital of the Chronos System Alliance. This isn't a planet; it's **Selene**, the smaller, outermost moon of the gas giant Chronos, locked in a perpetual dance with its colossal, ice-sheathed sister moon, **Veridia**, which dominates the cerulean sky with its majestic, frozen crescent.
#
# **Architecture & Design:** Aethelgard is a testament to adaptive engineering and aesthetic resilience. Its primary structures are a cluster of colossal, crystalline spires that seem to pierce the very heavens. Fashioned from a blend of hyper-durable alloys and self-repairing bio-luminescent synthetics, these towers gleam with an internal, cerulean light that pulses with the city's immense power grid. They are not merely buildings but integrated ecosystems, housing residential modules, advanced research laboratories, atmospheric processors, and zero-G hydroponic farms.
#
# The city is built on vast, reinforced platforms that seamlessly merge with the rugged mountain peaks, defying the harsh gravitational dynamics and occasional seismic tremors of Selene. Intricate sky-bridges of shimmering force fields and magnetic levitation conduits crisscross between the spires, allowing effortless traversal between the towering structures.
#
# **Purpose & Function:** Aethelgard serves as the paramount scientific and strategic hub for the Alliance. It is a bastion of knowledge, dedicated to deep-space astrophysics, xenobotanical research into Selene's unique extremophiles, and the study of Veridia's enigmatic cryo-volcanic activity. The glowing blue pools shimmering in the valleys below are not natural formations but "Aether Wells"—advanced energy conduits tapping into Selene's geothermal core, purified and amplified by proprietary alien technology discovered millennia ago. These wells provide the boundless energy that powers Aethelgard and fuels its ambitious terraforming experiments across other Chronos system bodies.
#
# **Atmosphere & Inhabitants:** Life in Aethelgard is structured, efficient, and intellectually vibrant. The air within the city's enclosed environments is recycled and oxygenated, carrying a faint, metallic tang. Citizens, primarily scholars, engineers, astrogators, and specialized technicians, move with a quiet purpose, their lives governed by the relentless pursuit of knowledge and the observation of the cosmos. Despite its remote and somewhat stark beauty, Aethelgard stands as a beacon of humanity's enduring drive to explore, understand, and harness the universe's most formidable challenges. The ever-present, majestic Veridia in the sky serves as a constant, awe-inspiring reminder of both the vastness of space and the delicate balance of their existence.

# %%
## Audio Input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.59it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# In a sunny spot, where shadows play,
# A little cat naps through the day.
# Her fur is soft, her whiskers long,
# She purrs a gentle, cozy song.
#
# With golden eyes that calm and gleam,
# She wakes and stretches from her dream.
# A leap, a bound, a playful race,
# Graceful steps fill every space.
#
# At dusk she roams the garden near,
# Her silhouette will disappear.
# With moonlit purrs and tender light,
# She finds her home and sleeps till night.
